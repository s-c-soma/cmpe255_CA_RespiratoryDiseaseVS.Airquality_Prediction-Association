# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.utils import resample

# %%
airQ_data = pd.read_csv('../Datasets/AirQuality/AirQualityData_2/AirQualityData_2_byCounty_Monthly.csv', low_memory =False)
airQ_data.tail()
# Out:
#      County  Year  MonthNo     Value
# 3535   Yolo  2019        8  6.658065
# 3536   Yolo  2019        9  5.130000
# 3537   Yolo  2019       10  9.777419
# 3538   Yolo  2019       11  8.803333
# 3539   Yolo  2019       12  0.000000

# %%
#monthly -> yearly Mean value: method 1
airQ_data_mean = airQ_data.groupby(['County','Year'])['Value'].mean().reset_index()
airQ_data_mean.head()
# Out:
#     County  Year      Value
# 0  Alameda  2014  10.615572
# 1  Alameda  2015  11.195880
# 2  Alameda  2016   9.924854
# 3  Alameda  2017  13.576661
# 4  Alameda  2018  16.584750

# %%
len(airQ_data_mean)
# Out:
# 295

# %%
#monthly -> yearly Mean value: method 2
airQ_data_mean1 = airQ_data.groupby(['County','Year'], as_index=False)['Value'].mean()
airQ_data_mean1.head()
# Out:
#     County  Year      Value
# 0  Alameda  2014  10.615572
# 1  Alameda  2015  11.195880
# 2  Alameda  2016   9.924854
# 3  Alameda  2017  13.576661
# 4  Alameda  2018  16.584750

# %%
#dropping 0 values
indexNames = airQ_data_mean[ (airQ_data_mean['Value'] == 0.000000)].index
airQ_data_mean.drop(indexNames , inplace=True)
airQ_data_mean.head()
# Out:
#     County  Year      Value
# 0  Alameda  2014  10.615572
# 1  Alameda  2015  11.195880
# 2  Alameda  2016   9.924854
# 3  Alameda  2017  13.576661
# 4  Alameda  2018  16.584750

# %%
len(airQ_data_mean)
# Out:
# 295

# %%
airQ_data_mean['County'].unique()
# Out:
# array(['Alameda', 'Butte', 'Calaveras', 'Colusa', 'Contra Costa',
#        'Del Norte', 'El Dorado', 'Fresno', 'Glenn', 'Humboldt',
#        'Humboldt ', 'Imperial', 'Inyo', 'Kern', 'Kings', 'LA', 'Lake',
#        'Madera', 'Marin', 'Mariposa', 'Mendocino', 'Merced', 'Mono',
#        'Monterey', 'Napa', 'Nevada', 'Orange', 'Placer', 'Plumas',
#        'Riverside', 'Sacramento', 'San Benito', 'San Bernardino',
#        'San Diego', 'San Francisco', 'San Joaquin', 'San Luis Obispo',
#        'San Mateo', 'Santa Barbara', 'Santa Clara', 'Santa Cruz',
#        'Shasta', 'Solano', 'Sonoma', 'Stanislaus', 'Sutter', 'Tehama',
#        'Trinity', 'Tulare', 'Ventura', 'Yolo'], dtype=object)

# %%
airQ_data_mean
# Out:
#       County  Year      Value
# 0    Alameda  2014  10.615572
# 1    Alameda  2015  11.195880
# 2    Alameda  2016   9.924854
# 3    Alameda  2017  13.576661
# 4    Alameda  2018  16.584750
# ..       ...   ...        ...
# 290     Yolo  2015  11.344165
# 291     Yolo  2016  10.715124
# 292     Yolo  2017  10.430445
# 293     Yolo  2018  12.856578
# 294     Yolo  2019   6.320492
#
# [295 rows x 3 columns]

# %%
#we will use this asthma4 data
ashtma4 = pd.read_csv('../Datasets/Disease cases/asthma-4/asthma_2014_17_final.csv', low_memory=False)
ashtma4.head()
# Out:
#    CountyCode  Crude rates per 10,000  Lower 95% Limit  Upper 95% Limit  \
# 0        6000                    48.5             48.5             48.7
# 1        6001                    63.2             62.0             64.5
# 2        6003                     NaN              NaN              NaN
# 3        6005                    61.9             54.1             70.4
# 4        6007                    43.8             41.1             46.6
#
#   Patient_count  Year
# 0       186,540  2014
# 1         9,909  2014
# 2           NaN  2014
# 3           227  2014
# 4           978  2014

# %%
#county-countycode mapping file
county_code = pd.read_csv('../Datasets/Disease cases/asthma-4/County_codes.csv',low_memory=False)
county_code.head()
# Out:
#                  County  CountyCode
# 0              Alameda         6001
# 1               Amador         6005
# 2                Butte         6007
# 3            Calaveras         6009
# 4  California/Statewide        6000

# %%
#merging asthma4 data with county code data to get county names

ashtma4_final = pd.merge(ashtma4,county_code, on='CountyCode')
ashtma4_final.head()
# Out:
#    CountyCode  Crude rates per 10,000  Lower 95% Limit  Upper 95% Limit  \
# 0        6000                    48.5             48.5             48.7
# 1        6000                    49.4             49.4             49.6
# 2        6000                    44.2             44.2             44.5
# 3        6000                    45.2             45.2             45.4
# 4        6001                    63.2             62.0             64.5
#
#   Patient_count  Year                County
# 0       186,540  2014  California/Statewide
# 1       191,480  2015  California/Statewide
# 2       174,119  2016  California/Statewide
# 3       179,503  2017  California/Statewide
# 4         9,909  2014              Alameda

# %%
ashtma4_final['County'].unique()
# Out:
# array(['California/Statewide', 'Alameda ', 'Amador ', 'Butte ',
#        'Calaveras ', 'Colusa ', 'Contra Costa ', 'Del Norte ',
#        'El Dorado ', 'Fresno ', 'Glenn ', 'Humboldt ', 'Imperial ',
#        'Inyo ', 'Kern ', 'Kings ', 'Lake ', 'Lassen ', 'Los Angeles ',
#        'Madera ', 'Marin ', 'Mariposa ', 'Mendocino ', 'Merced ',
#        'Modoc ', 'Mono ', 'Monterey ', 'Napa ', 'Nevada ', 'Orange ',
#        'Placer ', 'Plumas ', 'Riverside ', 'Sacramento ', 'San Benito ',
#        'San Bernardino ', 'San Diego ', 'San Francisco ', 'San Joaquin ',
#        'San Luis Obispo ', 'San Mateo ', 'Santa Barbara ', 'Santa Clara ',
#        'Santa Cruz ', 'Shasta ', 'Siskiyou ', 'Solano ', 'Sonoma ',
#        'Stanislaus ', 'Sutter ', 'Tehama ', 'Trinity ', 'Tulare ',
#        'Tuolumne ', 'Ventura ', 'Yolo ', 'Yuba '], dtype=object)

# %%
ashtma4_final['County'] = ashtma4_final['County'].str.strip()
ashtma4_final['County']
# Out:
# 0      California/Statewide
# 1      California/Statewide
# 2      California/Statewide
# 3      California/Statewide
# 4                   Alameda
#                ...
# 223                    Yolo
# 224                    Yuba
# 225                    Yuba
# 226                    Yuba
# 227                    Yuba
# Name: County, Length: 228, dtype: object

# %%
ashtma4_final
# Out:
#      CountyCode  Crude rates per 10,000  Lower 95% Limit  Upper 95% Limit  \
# 0          6000                    48.5             48.5             48.7
# 1          6000                    49.4             49.4             49.6
# 2          6000                    44.2             44.2             44.5
# 3          6000                    45.2             45.2             45.4
# 4          6001                    63.2             62.0             64.5
# ..          ...                     ...              ...              ...
# 223        6113                    40.4             37.8             43.2
# 224        6115                    43.4             38.8             48.4
# 225        6115                    45.6             40.9             50.7
# 226        6115                    38.9             34.6             43.6
# 227        6115                    47.6             42.8             52.7
#
#     Patient_count  Year                County
# 0         186,540  2014  California/Statewide
# 1         191,480  2015  California/Statewide
# 2         174,119  2016  California/Statewide
# 3         179,503  2017  California/Statewide
# 4           9,909  2014               Alameda
# ..            ...   ...                   ...
# 223           890  2017                  Yolo
# 224           323  2014                  Yuba
# 225           345  2015                  Yuba
# 226           296  2016                  Yuba
# 227           366  2017                  Yuba
#
# [228 rows x 7 columns]

# %%
airQ_data_mean['Year'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019])

# %%
#merging AQ data && asthma4 data

merged = pd.merge(airQ_data_mean,ashtma4_final,how='inner', left_on=['Year', 'County'], right_on=['Year','County'])

# %%
merged['Patient_count'] = merged['Patient_count'].str.replace(',','').astype(int)

# %%
len(merged)
# Out:
# 196

# %%
merged
# Out:
#       County  Year      Value  CountyCode  Crude rates per 10,000  \
# 0    Alameda  2014  10.615572        6001                    63.2
# 1    Alameda  2015  11.195880        6001                    62.9
# 2    Alameda  2016   9.924854        6001                    55.4
# 3    Alameda  2017  13.576661        6001                    53.9
# 4      Butte  2014  11.526889        6007                    43.8
# ..       ...   ...        ...         ...                     ...
# 191  Ventura  2017  17.019749        6111                    32.9
# 192     Yolo  2014   9.245116        6113                    39.2
# 193     Yolo  2015  11.344165        6113                    40.7
# 194     Yolo  2016  10.715124        6113                    35.4
# 195     Yolo  2017  10.430445        6113                    40.4
#
#      Lower 95% Limit  Upper 95% Limit  Patient_count
# 0               62.0             64.5           9909
# 1               61.7             64.2           9929
# 2               54.3             56.5           9073
# 3               52.7             55.0           8916
# 4               41.1             46.6            978
# ..               ...              ...            ...
# 191             31.7             34.1           2826
# 192             36.6             42.0            813
# 193             38.0             43.5            851
# 194             33.0             38.0            768
# 195             37.8             43.2            890
#
# [196 rows x 8 columns]

# %%
merged2_filtered = ashtma4_final[ashtma4_final['County'] == 'Santa Clara']

# %%
merged2_filtered
# Out:
#      CountyCode  Crude rates per 10,000  Lower 95% Limit  Upper 95% Limit  \
# 168        6085                    30.3             29.6             31.1
# 169        6085                    34.8             33.9             35.6
# 170        6085                    28.6             27.9             29.4
# 171        6085                    30.0             29.2             30.7
#
#     Patient_count  Year       County
# 168         5,643  2014  Santa Clara
# 169         6,514  2015  Santa Clara
# 170         5,522  2016  Santa Clara
# 171         5,849  2017  Santa Clara

# %%
corr = merged.corr()
g = sns.heatmap(corr, vmax=.9, center=0,
               square=True, linewidths=.9, cbar_kws={"shrink": .8}, annot=True, fmt='.2f', cmap='coolwarm')
bottom, top = g.get_ylim()
g.set_ylim(bottom + 0.5, top - 0.5)
sns.despine()
g.figure.set_size_inches(16, 10)

# %%
sns.barplot(x='County', y='Patient_count', hue='Year', data=merged, saturation=0.8)

# %%
sns.barplot(x='County', y='Crude rates per 10,000', hue='Year', data=merged, saturation=0.8)

# %%
sns.barplot(x='County', y='Value', hue='Year', data=merged, saturation=0.8)

# %%
sns.barplot(x='Patient_count', y='Value', hue='Year', data=merged, saturation=0.8)

# %%
sns.barplot(x='Crude rates per 10,000', y='Value', hue='Year', data=merged, saturation=0.8)

# %%
merged
# Out:
#       County  Year      Value  CountyCode  Crude rates per 10,000  \
# 0    Alameda  2014  10.615572        6001                    63.2
# 1    Alameda  2015  11.195880        6001                    62.9
# 2    Alameda  2016   9.924854        6001                    55.4
# 3    Alameda  2017  13.576661        6001                    53.9
# 4      Butte  2014  11.526889        6007                    43.8
# ..       ...   ...        ...         ...                     ...
# 191  Ventura  2017  17.019749        6111                    32.9
# 192     Yolo  2014   9.245116        6113                    39.2
# 193     Yolo  2015  11.344165        6113                    40.7
# 194     Yolo  2016  10.715124        6113                    35.4
# 195     Yolo  2017  10.430445        6113                    40.4
#
#      Lower 95% Limit  Upper 95% Limit  Patient_count
# 0               62.0             64.5           9909
# 1               61.7             64.2           9929
# 2               54.3             56.5           9073
# 3               52.7             55.0           8916
# 4               41.1             46.6            978
# ..               ...              ...            ...
# 191             31.7             34.1           2826
# 192             36.6             42.0            813
# 193             38.0             43.5            851
# 194             33.0             38.0            768
# 195             37.8             43.2            890
#
# [196 rows x 8 columns]

# %%
#county population file
county_population = pd.read_csv('../Datasets/Disease cases/asthma-4/county_population.csv',low_memory=False)
county_population.head()
# Out:
#       County  Year   Population
# 0    Alameda  2014   1,588,576
# 1     Alpine  2014       1,163
# 2     Amador  2014      37,815
# 3      Butte  2014     223,137
# 4  Calaveras  2014      45,358

# %%
#remove comma from Population column
county_population['Population'] = county_population['Population'].str.replace(',','').astype(int)
county_population.head()
# Out:
#       County  Year  Population
# 0    Alameda  2014     1588576
# 1     Alpine  2014        1163
# 2     Amador  2014       37815
# 3      Butte  2014      223137
# 4  Calaveras  2014       45358

# %%
#merging merged data && county_population data to get population column

merged = pd.merge(merged,county_population,how='inner', left_on=['Year', 'County'], right_on=['Year','County'])
merged.head()
# Out:
#     County  Year      Value  CountyCode  Crude rates per 10,000  \
# 0  Alameda  2014  10.615572        6001                    63.2
# 1  Alameda  2015  11.195880        6001                    62.9
# 2  Alameda  2016   9.924854        6001                    55.4
# 3  Alameda  2017  13.576661        6001                    53.9
# 4    Butte  2014  11.526889        6007                    43.8
#
#    Lower 95% Limit  Upper 95% Limit  Patient_count  Population
# 0             62.0             64.5           9909     1588576
# 1             61.7             64.2           9929     1611770
# 2             54.3             56.5           9073     1629738
# 3             52.7             55.0           8916     1646405
# 4             41.1             46.6            978      223137

# %%
#Calculating patient ratio

merged['Patient_ratio'] = merged['Patient_count']/merged['Population']
merged.head()
# Out:
#     County  Year      Value  CountyCode  Crude rates per 10,000  \
# 0  Alameda  2014  10.615572        6001                    63.2
# 1  Alameda  2015  11.195880        6001                    62.9
# 2  Alameda  2016   9.924854        6001                    55.4
# 3  Alameda  2017  13.576661        6001                    53.9
# 4    Butte  2014  11.526889        6007                    43.8
#
#    Lower 95% Limit  Upper 95% Limit  Patient_count  Population  Patient_ratio
# 0             62.0             64.5           9909     1588576       0.006238
# 1             61.7             64.2           9929     1611770       0.006160
# 2             54.3             56.5           9073     1629738       0.005567
# 3             52.7             55.0           8916     1646405       0.005415
# 4             41.1             46.6            978      223137       0.004383

# %%
#Calculating patient percentage

merged['Patient_percent%'] = merged['Patient_ratio']* 10000
merged.head()
# Out:
#     County  Year      Value  CountyCode  Crude rates per 10,000  \
# 0  Alameda  2014  10.615572        6001                    63.2
# 1  Alameda  2015  11.195880        6001                    62.9
# 2  Alameda  2016   9.924854        6001                    55.4
# 3  Alameda  2017  13.576661        6001                    53.9
# 4    Butte  2014  11.526889        6007                    43.8
#
#    Lower 95% Limit  Upper 95% Limit  Patient_count  Population  Patient_ratio  \
# 0             62.0             64.5           9909     1588576       0.006238
# 1             61.7             64.2           9929     1611770       0.006160
# 2             54.3             56.5           9073     1629738       0.005567
# 3             52.7             55.0           8916     1646405       0.005415
# 4             41.1             46.6            978      223137       0.004383
#
#    Patient_percent%
# 0         62.376619
# 1         61.603082
# 2         55.671525
# 3         54.154354
# 4         43.829576

# %%
#again measuring the correlation - without applying county filter

corr = merged.corr()
g = sns.heatmap(corr, vmax=.9, center=0,
               square=True, linewidths=.9, cbar_kws={"shrink": .8}, annot=True, fmt='.2f', cmap='coolwarm')
bottom, top = g.get_ylim()
g.set_ylim(bottom + 0.5, top - 0.5)
sns.despine()
g.figure.set_size_inches(16, 10)

# %%
#plotting AQ index value vs. patient ratio
merged[['Value','Patient_percent%']].plot()

# %%
merged[['Value','Crude rates per 10,000']].plot()

# %%
merged['County'].unique()
# Out:
# array(['Alameda', 'Butte', 'Calaveras', 'Colusa', 'Contra Costa',
#        'Del Norte', 'El Dorado', 'Fresno', 'Glenn', 'Humboldt',
#        'Imperial', 'Inyo', 'Kern', 'Kings', 'Lake', 'Madera', 'Marin',
#        'Mariposa', 'Mendocino', 'Merced', 'Mono', 'Monterey', 'Napa',
#        'Nevada', 'Orange', 'Placer', 'Plumas', 'Riverside', 'Sacramento',
#        'San Benito', 'San Bernardino', 'San Diego', 'San Francisco',
#        'San Joaquin', 'San Luis Obispo', 'San Mateo', 'Santa Barbara',
#        'Santa Clara', 'Santa Cruz', 'Shasta', 'Solano', 'Sonoma',
#        'Stanislaus', 'Sutter', 'Tehama', 'Trinity', 'Tulare', 'Ventura',
#        'Yolo'], dtype=object)

# %%
merged_filter_for_plot = merged[(merged['County'].isin(['Santa Clara']))]
merged_filter_for_plot
# Out:
#           County  Year      Value  CountyCode  Crude rates per 10,000  \
# 148  Santa Clara  2014   9.421971        6085                    30.3
# 149  Santa Clara  2015  10.519511        6085                    34.8
# 150  Santa Clara  2016   9.400861        6085                    28.6
# 151  Santa Clara  2017  11.125765        6085                    30.0
#
#      Lower 95% Limit  Upper 95% Limit  Patient_count  Population  \
# 148             29.6             31.1           5643     1880197
# 149             33.9             35.6           6514     1905156
# 150             27.9             29.4           5522     1924582
# 151             29.2             30.7           5849     1937473
#
#      Patient_ratio  Patient_percent%
# 148       0.003001         30.012812
# 149       0.003419         34.191426
# 150       0.002869         28.691945
# 151       0.003019         30.188808

# %%
#plotting AQ index value vs. patient ratio
merged_filter_for_plot[['Value','Patient_percent%']].plot()

# %%
merged_filter_for_plot[['Value','Crude rates per 10,000']].plot()

# %%
merged_filter_for_plot
# Out:
#           County  Year      Value  CountyCode  Crude rates per 10,000  \
# 148  Santa Clara  2014   9.421971        6085                    30.3
# 149  Santa Clara  2015  10.519511        6085                    34.8
# 150  Santa Clara  2016   9.400861        6085                    28.6
# 151  Santa Clara  2017  11.125765        6085                    30.0
#
#      Lower 95% Limit  Upper 95% Limit  Patient_count  Population  \
# 148             29.6             31.1           5643     1880197
# 149             33.9             35.6           6514     1905156
# 150             27.9             29.4           5522     1924582
# 151             29.2             30.7           5849     1937473
#
#      Patient_ratio  Patient_percent%
# 148       0.003001         30.012812
# 149       0.003419         34.191426
# 150       0.002869         28.691945
# 151       0.003019         30.188808

# %%
plt.figure()

x = merged_filter_for_plot['Crude rates per 10,000']
y = merged_filter_for_plot['Value']


plt.plot(x,y)

# %%
plt.figure()

x = merged_filter_for_plot['Year']
y = merged_filter_for_plot['Patient_percent%']

plt.plot(x,y)

# %%
plt.figure()

x = merged_filter_for_plot['Value']
y = merged_filter_for_plot['Year']

plt.plot(y,x)

# %%
plt.figure()

x = merged_filter_for_plot['Year']
y1 = merged_filter_for_plot['Patient_ratio'] * 10000
y2 = merged_filter_for_plot['Value']

plt.plot(x,y1)
plt.plot(x,y2)

# %%
sns.distplot(merged_filter_for_plot['Patient_ratio'])
plt.show()

# %%
sns.distplot(merged_filter_for_plot['Patient_ratio']* 10000)
plt.show()

# %%
sns.distplot(merged_filter_for_plot['Value'])
plt.show()

# %%
# Method 1: on the same Axis
sns.distplot( (merged_filter_for_plot["Patient_percent%"]) , color="blue", label="Patient_ratio")
sns.distplot( merged_filter_for_plot["Value"] , color="red", label="Value")
plt.legend()
 
plt.show()

# %%
merged_filter_for_plot.Value = merged_filter_for_plot.Value.astype(float)
merged_filter_for_plot
# Out:
# c:\users\subar\appdata\local\programs\python\python37-32\lib\site-packages\pandas\core\generic.py:5208: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value
#           County  Year      Value  CountyCode  Crude rates per 10,000  \
# 148  Santa Clara  2014   9.421971        6085                    30.3
# 149  Santa Clara  2015  10.519511        6085                    34.8
# 150  Santa Clara  2016   9.400861        6085                    28.6
# 151  Santa Clara  2017  11.125765        6085                    30.0
#
#      Lower 95% Limit  Upper 95% Limit  Patient_count  Population  \
# 148             29.6             31.1           5643     1880197
# 149             33.9             35.6           6514     1905156
# 150             27.9             29.4           5522     1924582
# 151             29.2             30.7           5849     1937473
#
#      Patient_ratio  Patient_percent%
# 148       0.003001         30.012812
# 149       0.003419         34.191426
# 150       0.002869         28.691945
# 151       0.003019         30.188808

# %%
merged
# Out:
#       County  Year      Value  CountyCode  Crude rates per 10,000  \
# 0    Alameda  2014  10.615572        6001                    63.2
# 1    Alameda  2015  11.195880        6001                    62.9
# 2    Alameda  2016   9.924854        6001                    55.4
# 3    Alameda  2017  13.576661        6001                    53.9
# 4      Butte  2014  11.526889        6007                    43.8
# ..       ...   ...        ...         ...                     ...
# 191  Ventura  2017  17.019749        6111                    32.9
# 192     Yolo  2014   9.245116        6113                    39.2
# 193     Yolo  2015  11.344165        6113                    40.7
# 194     Yolo  2016  10.715124        6113                    35.4
# 195     Yolo  2017  10.430445        6113                    40.4
#
#      Lower 95% Limit  Upper 95% Limit  Patient_count  Population  \
# 0               62.0             64.5           9909     1588576
# 1               61.7             64.2           9929     1611770
# 2               54.3             56.5           9073     1629738
# 3               52.7             55.0           8916     1646405
# 4               41.1             46.6            978      223137
# ..               ...              ...            ...         ...
# 191             31.7             34.1           2826      855910
# 192             36.6             42.0            813      208820
# 193             38.0             43.5            851      211078
# 194             33.0             38.0            768      215413
# 195             37.8             43.2            890      218673
#
#      Patient_ratio  Patient_percent%
# 0         0.006238         62.376619
# 1         0.006160         61.603082
# 2         0.005567         55.671525
# 3         0.005415         54.154354
# 4         0.004383         43.829576
# ..             ...               ...
# 191       0.003302         33.017490
# 192       0.003893         38.933052
# 193       0.004032         40.316850
# 194       0.003565         35.652444
# 195       0.004070         40.700041
#
# [196 rows x 11 columns]

# %%
# Prep Training and Test data.
trainData, testData = train_test_split(merged, train_size=0.7, random_state=100)

# %%
#X and Y(target) for linear regression
Y_trainData = trainData[['Crude rates per 10,000']]
X_trainData= trainData.drop('Crude rates per 10,000', axis =1 )

Y_testData = testData[['Crude rates per 10,000']]
X_testData= testData.drop('Crude rates per 10,000', axis =1 )
X_trainData = X_trainData.drop('County', axis=1)

# %%
X_testData = X_testData.drop('County', axis=1)
X_testData
# Out:
#      Year      Value  CountyCode  Lower 95% Limit  Upper 95% Limit  \
# 97   2015  14.949750        6059             32.0             33.3
# 92   2014  14.907850        6057             33.8             41.5
# 166  2016   4.595440        6097             31.8             35.0
# 90   2016   8.107885        6055             28.0             33.9
# 69   2015   7.774019        6043             34.8             54.7
# 131  2017   9.513597        6075             35.6             38.1
# 75   2017  10.375732        6045             57.9             68.5
# 127  2017  14.292512        6073             30.4             31.6
# 110  2016  17.760540        6065             39.8             41.4
# 101  2015  13.077167        6061             28.5             32.1
# 81   2015   0.830613        6051             21.4             39.9
# 118  2016   4.468738        6069             40.7             51.9
# 178  2016   4.293005        6103             46.8             58.2
# 128  2014   7.561871        6075             36.0             38.6
# 65   2015   8.441100        6041             19.5             23.1
# 163  2017  12.862709        6095             84.8             90.3
# 31   2017  17.006978        6019             76.0             79.5
# 112  2014  12.380634        6067             66.9             69.6
# 52   2014  16.584288        6031             75.7             84.7
# 11   2017  11.168423        6009             38.0             50.5
# 74   2016   7.253238        6045             45.8             55.2
# 15   2017   7.169353        6011             21.0             35.1
# 167  2017   8.109572        6097             36.5             39.9
# 96   2014  16.186831        6059             30.7             31.9
# 150  2016   9.400861        6085             27.9             29.4
# 149  2015  10.519511        6085             33.9             35.6
# 158  2016  13.784866        6089             37.7             43.7
# 124  2014  13.526846        6073             34.6             36.0
# 173  2015  10.968999        6101             30.4             37.8
# 171  2017  13.849432        6099             53.7             57.6
# 64   2014  10.652174        6041             23.3             27.3
# 46   2016   6.932089        6027             38.8             59.3
# 177  2015   4.188918        6103             44.4             55.4
# 111  2017  17.773573        6065             41.2             42.8
# 115  2017  14.363299        6067             65.0             67.6
# 32   2014   7.211658        6021             31.4             46.1
# 152  2014   8.083801        6087             32.1             36.6
# 192  2014   9.245116        6113             36.6             42.0
# 119  2017   5.177920        6069             51.9             64.4
# 99   2017  12.544940        6059             27.8             28.9
# 41   2015  18.881285        6025             68.2             75.9
# 170  2016  13.349230        6099             48.7             52.5
# 59   2017   0.951068        6033             67.4             80.7
# 7    2017  14.337585        6007             38.7             44.0
# 82   2016   0.767522        6051             16.5             33.6
# 125  2015  14.944544        6073             35.4             36.7
# 28   2014  18.891568        6019             76.7             80.3
# 29   2015  17.737725        6019             78.5             82.0
# 123  2017  19.048279        6071             50.6             52.5
# 40   2014  23.185004        6025             77.2             85.4
# 85   2015   7.168889        6053             48.7             53.0
# 117  2015   4.456332        6069             43.9             55.6
# 151  2017  11.125765        6085             29.2             30.7
# 160  2014  11.230632        6095             76.2             81.6
# 1    2015  11.195880        6001             61.7             64.2
# 77   2015  12.579252        6047             85.1             92.2
# 168  2014  12.733660        6099             61.9             66.2
# 134  2016  14.188587        6077             55.6             59.0
# 157  2015  16.171723        6089             52.2             59.1
#
#      Patient_count  Population  Patient_ratio  Patient_percent%
# 97           10260     3152314       0.003255         32.547519
# 92             368       97842       0.003761         37.611660
# 166           1681      502475       0.003345         33.454401
# 90             439      141711       0.003098         30.978541
# 69              79       18172       0.004347         43.473476
# 131           3240      874008       0.003707         37.070599
# 75             563       89092       0.006319         63.193104
# 127          10323     3309509       0.003119         31.191938
# 110           9576     2346717       0.004081         40.805943
# 101           1123      370387       0.003032         30.319639
# 81              43       13868       0.003101         31.006634
# 118            267       56624       0.004715         47.153151
# 178            335       63946       0.005239         52.387952
# 128           3093      848448       0.003645         36.454797
# 65             541      262409       0.002062         20.616671
# 163           3844      436640       0.008804         88.035911
# 31            7775      995233       0.007812         78.122410
# 112           9987     1465964       0.006813         68.125820
# 52            1238      149754       0.008267         82.668910
# 11             197       45175       0.004361         43.608190
# 74             448       88721       0.005050         50.495373
# 15              62       22050       0.002812         28.117914
# 167           1937      504613       0.003839         38.385852
# 96            9767     3126918       0.003124         31.235229
# 150           5522     1924582       0.002869         28.691945
# 149           6514     1905156       0.003419         34.191426
# 158            724      177874       0.004070         40.702970
# 124          11286     3230269       0.003494         34.938267
# 173            335       96390       0.003475         34.754643
# 171           3070      549976       0.005582         55.820618
# 64             643      260622       0.002467         24.671747
# 46              90       18632       0.004830         48.303993
# 177            321       63839       0.005028         50.282743
# 111          10057     2382640       0.004221         42.209482
# 115          10105     1513415       0.006677         66.769525
# 32             109       28497       0.003825         38.249640
# 152            925      271134       0.003412         34.115972
# 192            813      208820       0.003893         38.933052
# 119            339       56879       0.005960         59.600204
# 99            9069     3198968       0.002835         28.349768
# 41            1386      184569       0.007509         75.093867
# 170           2757      541006       0.005096         50.960618
# 59             481       64740       0.007430         74.297189
# 7              935      226403       0.004130         41.298039
# 82              33       13676       0.002413         24.129863
# 125          11629     3264449       0.003562         35.623163
# 28            7633      964611       0.007913         79.130344
# 29            7933      975043       0.008136         81.360514
# 123          11181     2155590       0.005187         51.869790
# 40            1515      182006       0.008324         83.239014
# 85            2192      432740       0.005065         50.653972
# 117            284       56452       0.005031         50.308226
# 151           5849     1937473       0.003019         30.188808
# 160           3321      423371       0.007844         78.441839
# 1             9929     1611770       0.006160         61.603082
# 77            2420      269111       0.008993         89.925718
# 168           3421      529850       0.006457         64.565443
# 134           4233      735319       0.005757         57.566852
# 157           1010      179004       0.005642         56.423320

# %%
# Creating linear regression model.
model1= LinearRegression()

# %%
model1.fit(X_trainData,Y_trainData)
predictions = model1.predict(X_testData)

# %%
# Get the slope and intercept of the line best fit.
print(model1.intercept_)


print(model1.coef_)
# Out:
# [-1.22046155]
# [[ 1.89417851e-03 -1.43544090e-03 -4.26556184e-04  5.49788586e-01
#    4.42685819e-01 -4.04820480e-05  9.43340937e-08  1.31436999e-06
#    1.31436999e-02]]

# %%
# print the R-squared value for the model
model1.score(X_trainData, Y_trainData)
# Out:
# 0.9999790579407943

# %%
# print the R-squared value for the model
print(model1.score(X_testData,Y_testData)  )
# Out:
# 0.9999769116877689

# %%
#X and Y(target) for logistic regression 
X_trainData = trainData[['Value','CountyCode']]
Y_trainData= trainData.Patient_ratio
X_testData= testData[['Value','CountyCode']]
Y_testData= testData.Patient_ratio

# %%
Y_trainData = trainData[['Crude rates per 10,000']]
X_trainData= trainData.drop('Crude rates per 10,000', axis =1 )

Y_testData = testData[['Crude rates per 10,000']]
X_testData= testData.drop('Crude rates per 10,000', axis =1 )
X_trainData = X_trainData.drop('County', axis=1)
X_testData = X_testData.drop('County', axis=1)

# %%
X_testData
# Out:
#      Year      Value  CountyCode  Lower 95% Limit  Upper 95% Limit  \
# 97   2015  14.949750        6059             32.0             33.3
# 92   2014  14.907850        6057             33.8             41.5
# 166  2016   4.595440        6097             31.8             35.0
# 90   2016   8.107885        6055             28.0             33.9
# 69   2015   7.774019        6043             34.8             54.7
# 131  2017   9.513597        6075             35.6             38.1
# 75   2017  10.375732        6045             57.9             68.5
# 127  2017  14.292512        6073             30.4             31.6
# 110  2016  17.760540        6065             39.8             41.4
# 101  2015  13.077167        6061             28.5             32.1
# 81   2015   0.830613        6051             21.4             39.9
# 118  2016   4.468738        6069             40.7             51.9
# 178  2016   4.293005        6103             46.8             58.2
# 128  2014   7.561871        6075             36.0             38.6
# 65   2015   8.441100        6041             19.5             23.1
# 163  2017  12.862709        6095             84.8             90.3
# 31   2017  17.006978        6019             76.0             79.5
# 112  2014  12.380634        6067             66.9             69.6
# 52   2014  16.584288        6031             75.7             84.7
# 11   2017  11.168423        6009             38.0             50.5
# 74   2016   7.253238        6045             45.8             55.2
# 15   2017   7.169353        6011             21.0             35.1
# 167  2017   8.109572        6097             36.5             39.9
# 96   2014  16.186831        6059             30.7             31.9
# 150  2016   9.400861        6085             27.9             29.4
# 149  2015  10.519511        6085             33.9             35.6
# 158  2016  13.784866        6089             37.7             43.7
# 124  2014  13.526846        6073             34.6             36.0
# 173  2015  10.968999        6101             30.4             37.8
# 171  2017  13.849432        6099             53.7             57.6
# 64   2014  10.652174        6041             23.3             27.3
# 46   2016   6.932089        6027             38.8             59.3
# 177  2015   4.188918        6103             44.4             55.4
# 111  2017  17.773573        6065             41.2             42.8
# 115  2017  14.363299        6067             65.0             67.6
# 32   2014   7.211658        6021             31.4             46.1
# 152  2014   8.083801        6087             32.1             36.6
# 192  2014   9.245116        6113             36.6             42.0
# 119  2017   5.177920        6069             51.9             64.4
# 99   2017  12.544940        6059             27.8             28.9
# 41   2015  18.881285        6025             68.2             75.9
# 170  2016  13.349230        6099             48.7             52.5
# 59   2017   0.951068        6033             67.4             80.7
# 7    2017  14.337585        6007             38.7             44.0
# 82   2016   0.767522        6051             16.5             33.6
# 125  2015  14.944544        6073             35.4             36.7
# 28   2014  18.891568        6019             76.7             80.3
# 29   2015  17.737725        6019             78.5             82.0
# 123  2017  19.048279        6071             50.6             52.5
# 40   2014  23.185004        6025             77.2             85.4
# 85   2015   7.168889        6053             48.7             53.0
# 117  2015   4.456332        6069             43.9             55.6
# 151  2017  11.125765        6085             29.2             30.7
# 160  2014  11.230632        6095             76.2             81.6
# 1    2015  11.195880        6001             61.7             64.2
# 77   2015  12.579252        6047             85.1             92.2
# 168  2014  12.733660        6099             61.9             66.2
# 134  2016  14.188587        6077             55.6             59.0
# 157  2015  16.171723        6089             52.2             59.1
#
#      Patient_count  Population  Patient_ratio  Patient_percent%
# 97           10260     3152314       0.003255         32.547519
# 92             368       97842       0.003761         37.611660
# 166           1681      502475       0.003345         33.454401
# 90             439      141711       0.003098         30.978541
# 69              79       18172       0.004347         43.473476
# 131           3240      874008       0.003707         37.070599
# 75             563       89092       0.006319         63.193104
# 127          10323     3309509       0.003119         31.191938
# 110           9576     2346717       0.004081         40.805943
# 101           1123      370387       0.003032         30.319639
# 81              43       13868       0.003101         31.006634
# 118            267       56624       0.004715         47.153151
# 178            335       63946       0.005239         52.387952
# 128           3093      848448       0.003645         36.454797
# 65             541      262409       0.002062         20.616671
# 163           3844      436640       0.008804         88.035911
# 31            7775      995233       0.007812         78.122410
# 112           9987     1465964       0.006813         68.125820
# 52            1238      149754       0.008267         82.668910
# 11             197       45175       0.004361         43.608190
# 74             448       88721       0.005050         50.495373
# 15              62       22050       0.002812         28.117914
# 167           1937      504613       0.003839         38.385852
# 96            9767     3126918       0.003124         31.235229
# 150           5522     1924582       0.002869         28.691945
# 149           6514     1905156       0.003419         34.191426
# 158            724      177874       0.004070         40.702970
# 124          11286     3230269       0.003494         34.938267
# 173            335       96390       0.003475         34.754643
# 171           3070      549976       0.005582         55.820618
# 64             643      260622       0.002467         24.671747
# 46              90       18632       0.004830         48.303993
# 177            321       63839       0.005028         50.282743
# 111          10057     2382640       0.004221         42.209482
# 115          10105     1513415       0.006677         66.769525
# 32             109       28497       0.003825         38.249640
# 152            925      271134       0.003412         34.115972
# 192            813      208820       0.003893         38.933052
# 119            339       56879       0.005960         59.600204
# 99            9069     3198968       0.002835         28.349768
# 41            1386      184569       0.007509         75.093867
# 170           2757      541006       0.005096         50.960618
# 59             481       64740       0.007430         74.297189
# 7              935      226403       0.004130         41.298039
# 82              33       13676       0.002413         24.129863
# 125          11629     3264449       0.003562         35.623163
# 28            7633      964611       0.007913         79.130344
# 29            7933      975043       0.008136         81.360514
# 123          11181     2155590       0.005187         51.869790
# 40            1515      182006       0.008324         83.239014
# 85            2192      432740       0.005065         50.653972
# 117            284       56452       0.005031         50.308226
# 151           5849     1937473       0.003019         30.188808
# 160           3321      423371       0.007844         78.441839
# 1             9929     1611770       0.006160         61.603082
# 77            2420      269111       0.008993         89.925718
# 168           3421      529850       0.006457         64.565443
# 134           4233      735319       0.005757         57.566852
# 157           1010      179004       0.005642         56.423320

# %%
# Creating Logistic regression model.
model2= LogisticRegression()

# %%
model2.fit(X_trainData,Y_trainData)
predictions = model2.predict(X_testData)
# Out:
# /Users/jeyasri/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/jeyasri/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-a1cc5711b28c> in <module>
# ----> 1 model2.fit(X_trainData,Y_trainData)
#       2 predictions = model2.predict(X_testData)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py in fit(self, X, y, sample_weight)
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
#    1532                          accept_large_sparse=solver != 'liblinear')
# -> 1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#    1535         n_samples, n_features = X.shape
#
# ~/opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/multiclass.py in check_classification_targets(y)
#     167     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     168                       'multilabel-indicator', 'multilabel-sequences']:
# --> 169         raise ValueError("Unknown label type: %r" % y_type)
#     170
#     171
#
# ValueError: Unknown label type: 'continuous'

# %%
X_train, X_test, y_train, y_test = train_test_split(
    merged.drop(labels=['Crude rates per 10,000', 'County'], axis=1),
    merged['Crude rates per 10,000'],
    test_size=0.3,
    random_state=0)
X_train.shape, X_test.shape
# Out:
# ((137, 9), (59, 9))

# %%
from sklearn import linear_model

clf = linear_model.LinearRegression()
clf.fit(X_train, y_train)
predictions = clf.predict(X_test)

# %%
print(clf.intercept_)


print(clf.coef_)
# Out:
# -8.519089071670699
# [ 5.02347414e-03 -1.85770679e-03 -2.62352823e-04  5.48084967e-01
#   4.41697164e-01 -4.20980210e-05  1.01778567e-07  1.57676871e-06
#   1.57676871e-02]

# %%
np.round(clf.coef_, decimals=2) > 0
# Out:
# array([ True, False, False,  True,  True, False, False, False,  True])

# %%
from sklearn.feature_selection import RFE
selector = RFE(clf, n_features_to_select=1)
selector = selector.fit(X_train, y_train)

# %%
order = selector.ranking_
order
# Out:
# array([4, 5, 6, 1, 2, 7, 9, 8, 3])

# %%
feature_ranks = []

for i in order:
    feature_ranks.append(f"{i}.{merged.columns[i]}")

feature_ranks
# Out:
# ['4.Crude rates per 10,000',
#  '5.Lower 95% Limit',
#  '6.Upper 95% Limit',
#  '1.Year',
#  '2.Value',
#  '7.Patient_count',
#  '9.Patient_ratio',
#  '8.Population',
#  '3.CountyCode']

# %% [markdown]
# ## Below code is reference from
#
# https://github.com/kidaufo/StatisticalModeling/blob/master/GLM.ipynb
# https://towardsdatascience.com/generalized-linear-models-9cbf848bb8ab

# %%
# Poisson regression code

import statsmodels.api as sm
np.random.seed(5)
n_sample = 100
a = 0.6
b = -0.4

x = uniform(1, 5, size=n_sample)
mu = np.exp(a * x + b)
y = poisson(mu)

exog, endog = sm.add_constant(x), y

# Poisson regression
mod = sm.GLM(endog, exog, family=sm.families.Poisson(link=sm.families.links.log()))
res = mod.fit()
display(res.summary())

y_pred = res.predict(exog)

idx = x.argsort()
x_ord, y_pred_ord = x[idx], y_pred[idx]
plt.plot(x_ord, y_pred_ord, color='m')
plt.scatter(x, y,  s=20, alpha=0.8)
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       98
# Model Family:                 Poisson   Df Model:                            1
# Link Function:                    log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -213.95
# Date:                Fri, 22 Nov 2019   Deviance:                       120.86
# Time:                        08:23:13   Pearson chi2:                     115.
# No. Iterations:                     5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2789      0.162     -1.720      0.085      -0.597       0.039
# x1             0.5646      0.042     13.508      0.000       0.483       0.647
# ==============================================================================
# """
# Text(0, 0.5, 'Y')

# %%
# Normal distribution + log link function
from numpy.random import uniform, normal, poisson, binomial


np.random.seed(5)
n_sample = 100
a = 0.6
b = -0.4

x = uniform(1, 5, size=n_sample)
mu = np.exp(a * x + b)
y = poisson(mu)
exog, endog = sm.add_constant(x), y


mod = sm.GLM(endog, exog, family=sm.families.Gaussian(sm.families.links.log()))
res = mod.fit()
display(res.summary())

y_pred = res.predict(exog)

idx = x.argsort()
x_ord, y_pred_ord = x[idx], y_pred[idx]

plt.plot(x_ord, y_pred_ord, color='m')
plt.scatter(x, y,  s=20, alpha=0.8)
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       98
# Model Family:                Gaussian   Df Model:                            1
# Link Function:                    log   Scale:                          6.1765
# Method:                          IRLS   Log-Likelihood:                -231.93
# Date:                Fri, 22 Nov 2019   Deviance:                       605.30
# Time:                        08:25:54   Pearson chi2:                     605.
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2369      0.224     -1.059      0.290      -0.675       0.202
# x1             0.5541      0.052     10.583      0.000       0.451       0.657
# ==============================================================================
# """
# Text(0, 0.5, 'Y')

# %%
def logistic(x):
    return 1 / (1 + np.exp(-x))


xx = np.linspace(-8, 8)
plt.plot(xx, logistic(xx))

# %%
#logistic regression


np.random.seed(5)
n_sample = 100
a = 3.0
b = -9.0

x = uniform(1, 5, size=n_sample)
x = np.sort(x)

q = logistic(a * x + b)
y = binomial(n=1, p=q)

exog, endog = sm.add_constant(X_train), y_train

# Logistic regression
mod = sm.GLM(endog, exog, family=sm.families.Binomial(link=sm.families.links.logit()))
res = mod.fit()
display(res.summary())

y_pred = res.predict(exog)

idx = x.argsort()
x_ord, y_pred_ord = x[idx], y_pred[idx]
plt.plot(x_ord, y_pred_ord, color='m')
plt.scatter(x, y,  s=20, alpha=0.8)
plt.xlabel("X")
plt.ylabel("Y")
# plt.savefig('logistic_regression.png')
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       98
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -31.508
# Date:                Fri, 22 Nov 2019   Deviance:                       63.016
# Time:                        08:19:27   Pearson chi2:                     109.
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -7.0444      1.385     -5.087      0.000      -9.758      -4.330
# x1             2.4211      0.465      5.207      0.000       1.510       3.332
# ==============================================================================
# """
# Text(0, 0.5, 'Y')

# %%
np.random.seed(5)
n_sample = 100
a = 0.6
b = -0.4
sd = 0.8

x = uniform(1, 5, size=n_sample)
mu = np.exp(a * x + b)
y = normal(mu, sd)

# %%
plt.scatter(x, y,  s=20, alpha=0.8)
plt.xlabel("X")
plt.ylabel("Y")
# plt.savefig('custom_GLM_data.png')
# Out:
# Text(0, 0.5, 'Y')

# %%
exog = sm.add_constant(x)
endog = y

# Normal distribution + log link function
mod = sm.GLM(endog, exog, family=sm.families.Gaussian(sm.families.links.log()))
res = mod.fit()
display(res.summary())

y_pred = res.predict(exog)

idx = x.argsort()
x_ord, y_pred_ord = x[idx], y_pred[idx]

plt.plot(x_ord, y_pred_ord, color='m')
plt.scatter(x, y,  s=20, alpha=0.8)
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  100
# Model:                            GLM   Df Residuals:                       98
# Model Family:                Gaussian   Df Model:                            1
# Link Function:                    log   Scale:                         0.69261
# Method:                          IRLS   Log-Likelihood:                -122.53
# Date:                Fri, 22 Nov 2019   Deviance:                       67.876
# Time:                        08:20:36   Pearson chi2:                     67.9
# No. Iterations:                     6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3115      0.075     -4.130      0.000      -0.459      -0.164
# x1             0.5789      0.018     32.984      0.000       0.545       0.613
# ==============================================================================
# """
# Text(0, 0.5, 'Y')
