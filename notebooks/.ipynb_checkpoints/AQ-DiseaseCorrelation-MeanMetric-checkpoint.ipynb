# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
airQ_data = pd.read_csv('../Datasets/AirQuality/AQData_monthly_2014_2019.csv', low_memory =False)
airQ_data.tail()
# Out:
#      AirQualityIndex  Year  MonthNo MonthName                Zone  \
# 2173             aqi  2019        7       Jul  Santa Clara Valley
# 2174             aqi  2019        8       Aug  Santa Clara Valley
# 2175             aqi  2019        9       Sep  Santa Clara Valley
# 2176             aqi  2019       10       Oct  Santa Clara Valley
# 2177             aqi  2019       11       Nov  Santa Clara Valley
#
#                    Station  Value
# 2173  San Martin - Airport    0.0
# 2174  San Martin - Airport    0.0
# 2175  San Martin - Airport    0.0
# 2176  San Martin - Airport    0.0
# 2177  San Martin - Airport    0.0

# %%
#monthly -> yearly Mean value
res = df.groupby(['id', 'view'])['value'].mean().reset_index()

# %%
county_station = pd.read_csv('../Datasets/county_station.csv',low_memory=False)
county_station.head()
# Out:
#    No                     Station        County
# 0   1       Berkeley Aquatic Park       Alameda
# 1   2               Bethel Island  Contra Costa
# 2   3                     Concord  Contra Costa
# 3   4     Crockett - Kendall Ave.       Houston
# 4   5  Fairfield - Chadbourne Rd.        Solano

# %%
county_station = county_station.drop('No',axis=1)
county_station
# Out:
#                          Station         County
# 0          Berkeley Aquatic Park        Alameda
# 1                  Bethel Island   Contra Costa
# 2                        Concord   Contra Costa
# 3        Crockett - Kendall Ave.        Houston
# 4     Fairfield - Chadbourne Rd.         Solano
# 5                  Forest Knolls          Marin
# 6                         Gilroy    Santa Clara
# 7                        Hayward        Alameda
# 8                  Laney College        Alameda
# 9        Livermore - Rincon Ave.        Alameda
# 10                     Los Gatos    Santa Clara
# 11          Martinez - Jones St.   Contra Costa
# 12                          Napa           Napa
# 13    Napa - Napa Valley College           Napa
# 14                  Oakland East        Alameda
# 15                  Oakland West        Alameda
# 16        Pittsburg - Loveridge’   Contra Costa
# 17                    Pleasanton        Alameda
# 18        Pleasanton - Owens Ct.        Alameda
# ...

# %%
airQ_data = pd.merge(airQ_data,county_station, on='Station')

# %%
airQ_data
# Out:
#      AirQualityIndex  Year  MonthNo MonthName                Zone  \
# 0                aqi  2014        1       Jan       Northern Zone
# 1                aqi  2014        2       Feb       Northern Zone
# 2                aqi  2014        3       Mar       Northern Zone
# 3                aqi  2014        4       Apr       Northern Zone
# 4                aqi  2014        5       May       Northern Zone
# ...              ...   ...      ...       ...                 ...
# 1975             aqi  2019        7       Jul  Santa Clara Valley
# 1976             aqi  2019        8       Aug  Santa Clara Valley
# 1977             aqi  2019        9       Sep  Santa Clara Valley
# 1978             aqi  2019       10       Oct  Santa Clara Valley
# 1979             aqi  2019       11       Nov  Santa Clara Valley
#
#                    Station  Value County
# 0            Forest Knolls    0.0  Marin
# 1            Forest Knolls    0.0  Marin
# 2            Forest Knolls    0.0  Marin
# ...

# %%
ashtma_data4 = pd.read_csv('../Datasets/Disease cases/asthma-4/Asthmadata_by_county_2014_2017.csv', low_memory=False)
ashtma_data4.head()
# Out:
#      CountyName  CountyCode  Year  AgeAdjRate  Lower95%  Upper95%  Total
# 0        Marin         6041  2014        25.2      23.3      27.3  643.0
# 1       Placer         6061  2014        29.4      27.7      31.2    0.0
# 2  Santa Clara         6085  2014        30.3      29.6      31.1    0.0
# 3       Lassen         6035  2014        30.5      24.9      37.0  103.0
# 4       Orange         6059  2014        31.3      30.7      31.9    0.0

# %%
ashtma4 = pd.read_csv('../Datasets/Disease cases/asthma-4/asthma_2014_17.csv', low_memory=False)
ashtma4.head()
# Out:
#    CountyCode  Crude rates per 10,000  Lower 95% Limit  Upper 95% Limit  \
# 0        6000                    48.5             48.5             48.7
# 1        6001                    63.2             62.0             64.5
# 2        6003                     NaN              NaN              NaN
# 3        6005                    61.9             54.1             70.4
# 4        6007                    43.8             41.1             46.6
#
#   Patient_count  Year
# 0       186,540  2014
# 1         9,909  2014
# 2           NaN  2014
# 3           227  2014
# 4           978  2014

# %%
county_code = pd.read_csv('../Datasets/Disease cases/asthma-4/County_codes.csv',low_memory=False)
county_code.head()
# Out:
#                  County  CountyCode
# 0              Alameda         6001
# 1               Amador         6005
# 2                Butte         6007
# 3            Calaveras         6009
# 4  California/Statewide        6000

# %%
ashtma4 = pd.merge(ashtma4,county_code, on='CountyCode')

# %%
ashtma4['County'].unique()
# Out:
# array(['California/Statewide', 'Alameda ', 'Amador ', 'Butte ',
#        'Calaveras ', 'Colusa ', 'Contra Costa ', 'Del Norte ',
#        'El Dorado ', 'Fresno ', 'Glenn ', 'Humboldt ', 'Imperial ',
#        'Inyo ', 'Kern ', 'Kings ', 'Lake ', 'Lassen ', 'Los Angeles ',
#        'Madera ', 'Marin ', 'Mariposa ', 'Mendocino ', 'Merced ',
#        'Modoc ', 'Mono ', 'Monterey ', 'Napa ', 'Nevada ', 'Orange ',
#        'Placer ', 'Plumas ', 'Riverside ', 'Sacramento ', 'San Benito ',
#        'San Bernardino ', 'San Diego ', 'San Francisco ', 'San Joaquin ',
#        'San Luis Obispo ', 'San Mateo ', 'Santa Barbara ', 'Santa Clara ',
#        'Santa Cruz ', 'Shasta ', 'Siskiyou ', 'Solano ', 'Sonoma ',
#        'Stanislaus ', 'Sutter ', 'Tehama ', 'Trinity ', 'Tulare ',
#        'Tuolumne ', 'Ventura ', 'Yolo ', 'Yuba '], dtype=object)

# %%
ashtma4['County'] = ashtma4['County'].str.strip()
ashtma4['County']
# Out:
# 0      California/Statewide
# 1      California/Statewide
# 2      California/Statewide
# 3      California/Statewide
# 4                   Alameda
#                ...
# 223                    Yolo
# 224                    Yuba
# 225                    Yuba
# 226                    Yuba
# 227                    Yuba
# Name: County, Length: 228, dtype: object

# %%
ashtma4
# Out:
#      CountyCode  Crude rates per 10,000  Lower 95% Limit  Upper 95% Limit  \
# 0          6000                    48.5             48.5             48.7
# 1          6000                    49.4             49.4             49.6
# 2          6000                    44.2             44.2             44.5
# 3          6000                    45.2             45.2             45.4
# 4          6001                    63.2             62.0             64.5
# ..          ...                     ...              ...              ...
# 223        6113                    40.4             37.8             43.2
# 224        6115                    43.4             38.8             48.4
# 225        6115                    45.6             40.9             50.7
# 226        6115                    38.9             34.6             43.6
# 227        6115                    47.6             42.8             52.7
#
#     Patient_count  Year                County
# ...

# %%
airQ_data['Year'].unique()
# Out:
# array([2014, 2015, 2016, 2017, 2018, 2019], dtype=int64)

# %%
merged = pd.merge(airQ_data,ashtma4,how='inner', left_on=['Year', 'County'], right_on=['Year','County'])

# %%
merged['Patient_count'] = merged['Patient_count'].str.replace(',','').astype(int)

# %%
merged
# Out:
#      AirQualityIndex  Year  MonthNo MonthName                Zone  \
# 0                aqi  2014        1       Jan       Northern Zone
# 1                aqi  2014        2       Feb       Northern Zone
# 2                aqi  2014        3       Mar       Northern Zone
# 3                aqi  2014        4       Apr       Northern Zone
# 4                aqi  2014        5       May       Northern Zone
# ...              ...   ...      ...       ...                 ...
# 1271             aqi  2017        7       Jul  Santa Clara Valley
# 1272             aqi  2017        8       Aug  Santa Clara Valley
# 1273             aqi  2017        9       Sep  Santa Clara Valley
# 1274             aqi  2017       10       Oct  Santa Clara Valley
# 1275             aqi  2017       11       Nov  Santa Clara Valley
#
#                    Station  Value       County  CountyCode  \
# 0            Forest Knolls    0.0        Marin        6041
# ...

# %%
merged2_filtered = ashtma4[ashtma4['County'] == 'Santa Clara']

# %%
merged2_filtered
# Out:
#      CountyCode  Crude rates per 10,000  Lower 95% Limit  Upper 95% Limit  \
# 168        6085                    30.3             29.6             31.1
# 169        6085                    34.8             33.9             35.6
# 170        6085                    28.6             27.9             29.4
# 171        6085                    30.0             29.2             30.7
#
#     Patient_count  Year       County
# 168         5,643  2014  Santa Clara
# 169         6,514  2015  Santa Clara
# 170         5,522  2016  Santa Clara
# 171         5,849  2017  Santa Clara

# %%
corr = merged.corr()
g = sns.heatmap(corr, vmax=.9, center=0,
               square=True, linewidths=.9, cbar_kws={"shrink": .8}, annot=True, fmt='.2f', cmap='coolwarm')
bottom, top = g.get_ylim()
g.set_ylim(bottom + 0.5, top - 0.5)
sns.despine()
g.figure.set_size_inches(16, 10)

# %%
sns.barplot(x='County', y='Patient_count', hue='Year', data=merged, saturation=0.8)

# %%
sns.barplot(x='County', y='Value', hue='Year', data=merged2, saturation=0.8)

# %%
sns.barplot(x='Patient_count', y='Value', hue='Year', data=merged2, saturation=0.8)

# %%
merged
# Out:
#      AirQualityIndex  Year  MonthNo MonthName                Zone  \
# 0                aqi  2014        1       Jan       Northern Zone
# 1                aqi  2014        2       Feb       Northern Zone
# 2                aqi  2014        3       Mar       Northern Zone
# 3                aqi  2014        4       Apr       Northern Zone
# 4                aqi  2014        5       May       Northern Zone
# ...              ...   ...      ...       ...                 ...
# 1271             aqi  2017        7       Jul  Santa Clara Valley
# 1272             aqi  2017        8       Aug  Santa Clara Valley
# 1273             aqi  2017        9       Sep  Santa Clara Valley
# 1274             aqi  2017       10       Oct  Santa Clara Valley
# 1275             aqi  2017       11       Nov  Santa Clara Valley
#
#                    Station  Value       County  CountyCode  \
# 0            Forest Knolls    0.0        Marin        6041
# ...
