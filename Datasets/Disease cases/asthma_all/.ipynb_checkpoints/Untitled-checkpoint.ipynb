# %%
import pandas as pd

data_1 = pd.read_csv("chis-data-current-asthma-prevalence-by-county.csv", encoding = "ISO-8859-1")
data_2 = pd.read_csv("CA_Population_by_county_2016.csv", encoding = "ISO-8859-1")

data_comb = pd.merge(data_1, data_2, left_on=['COUNTY'], right_on = ['COUNTY'], how='left')
data_comb.to_csv (r'comb.csv', index = None, header=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-6-6cc573e1f5fb> in <module>
#       5
#       6 data_comb = pd.merge(data_1, data_2, left_on=['COUNTY'], right_on = ['COUNTY'], how='left')
# ----> 7 data_comb.to_csv (r'comb.csv', index = None, header=True)
#
# ~\AppData\Local\anaconda3\envs\manmeet_main\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    3018                                  doublequote=doublequote,
#    3019                                  escapechar=escapechar, decimal=decimal)
# -> 3020         formatter.save()
#    3021
#    3022         if path_or_buf is None:
#
# ~\AppData\Local\anaconda3\envs\manmeet_main\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     155             f, handles = _get_handle(self.path_or_buf, self.mode,
#     156                                      encoding=self.encoding,
# --> 157                                      compression=self.compression)
#     158             close = True
#     159
#
# ~\AppData\Local\anaconda3\envs\manmeet_main\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     422         elif encoding:
#     423             # Python 3 and encoding
# --> 424             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     425         elif is_text:
#     426             # Python 3 and no explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'comb.csv'
